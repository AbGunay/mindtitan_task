# %%
import pandas as pd
import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline
sns.set()
chefmozaccepts = pd.read_csv("chefmozaccepts.csv")
chefmozcuisine = pd.read_csv("chefmozcuisine.csv")
chefmozhours = pd.read_csv("chefmozhours4.csv")
chefmozparking = pd.read_csv("chefmozparking.csv")
geoplaces = pd.read_csv("geoplaces2.csv")
usercuisine = pd.read_csv("usercuisine.csv")
userpayment = pd.read_csv("userpayment.csv")
userprofile = pd.read_csv("userprofile.csv")
rating_final = pd.read_csv("rating_final.csv")

#chefmozhours#not use
#chefmozaccepts#not use
#chefmozcuisine#not use

# %%
places = chefmozparking.merge(geoplaces, on = "placeID", how = "inner")

# %%
rating_final = rating_final.iloc[:,0:3]

# %%
restaurants = places.merge(rating_final, on="placeID", how="inner")
restaurants = restaurants[["price","parking_lot","smoking_area","other_services","dress_code","accessibility","rating"]]
restaurants
# Out:
#        price parking_lot   smoking_area other_services dress_code  \
# 0     medium        none  not permitted       Internet   informal
# 1     medium        none  not permitted       Internet   informal
# 2     medium        none  not permitted       Internet   informal
# 3     medium        none  not permitted       Internet   informal
# 4        low        none           none           none   informal
# 5        low        none           none           none   informal
# 6        low        none           none           none   informal
# 7        low        none           none           none   informal
# 8        low        none           none           none   informal
# 9        low        none           none           none   informal
# 10       low        none           none           none   informal
# 11       low        none           none           none   informal
# 12       low        none           none           none   informal
# 13       low        none           none           none   informal
# 14       low        none           none           none   informal
# 15    medium        none    only at bar           none   informal
# 16    medium        none    only at bar           none   informal
# 17    medium        none    only at bar           none   informal
# 18    medium        none    only at bar           none   informal
# 19    medium        none    only at bar           none   informal
# 20    medium        none    only at bar           none   informal
# 21    medium        none    only at bar           none   informal
# 22    medium        none    only at bar           none   informal
# 23    medium        none    only at bar           none   informal
# 24    medium        none    only at bar           none   informal
# 25    medium         yes  not permitted        variety   informal
# 26    medium         yes  not permitted        variety   informal
# 27    medium         yes  not permitted        variety   informal
# 28    medium         yes  not permitted        variety   informal
# 29    medium         yes  not permitted        variety   informal
# ...      ...         ...            ...            ...        ...
# 1131     low        none  not permitted           none   informal
# 1132     low        none  not permitted           none   informal
# 1133     low        none  not permitted           none   informal
# 1134     low         yes  not permitted           none   informal
# 1135     low         yes  not permitted           none   informal
# 1136     low         yes  not permitted           none   informal
# 1137     low         yes  not permitted           none   informal
# 1138     low         yes  not permitted           none   informal
# 1139     low         yes  not permitted           none   informal
# 1140     low         yes  not permitted           none   informal
# 1141     low         yes  not permitted           none   informal
# 1142     low         yes  not permitted           none   informal
# 1143     low         yes  not permitted           none   informal
# 1144     low         yes  not permitted           none   informal
# 1145     low         yes  not permitted           none   informal
# 1146     low         yes  not permitted           none   informal
# 1147     low         yes  not permitted           none   informal
# 1148     low         yes  not permitted           none   informal
# 1149     low        none           none           none   informal
# 1150     low        none           none           none   informal
# 1151     low        none           none           none   informal
# 1152     low        none           none           none   informal
# 1153     low        none           none           none   informal
# 1154     low        none           none           none   informal
# 1155     low        none           none           none   informal
# 1156     low        none           none           none   informal
# 1157     low      public      permitted           none   informal
# 1158     low      public      permitted           none   informal
# 1159     low      public      permitted           none   informal
# 1160     low      public      permitted           none   informal
#
#          accessibility  rating
# 0     no_accessibility       0
# 1     no_accessibility       2
# 2     no_accessibility       1
# 3     no_accessibility       1
# 4           completely       2
# 5           completely       2
# 6           completely       1
# 7           completely       1
# 8           completely       0
# 9           completely       1
# 10          completely       1
# 11          completely       2
# 12          completely       0
# 13          completely       1
# 14          completely       2
# 15           partially       2
# 16           partially       2
# 17           partially       1
# 18           partially       2
# 19           partially       0
# 20           partially       2
# 21           partially       0
# 22           partially       0
# 23           partially       2
# 24           partially       1
# 25          completely       1
# 26          completely       0
# 27          completely       1
# 28          completely       2
# 29          completely       1
# ...                ...     ...
# 1131         partially       0
# 1132         partially       1
# 1133         partially       2
# 1134        completely       1
# 1135        completely       2
# 1136        completely       2
# 1137        completely       0
# 1138        completely       1
# 1139        completely       1
# 1140        completely       1
# 1141        completely       2
# 1142        completely       1
# 1143        completely       1
# 1144        completely       1
# 1145        completely       1
# 1146        completely       0
# 1147        completely       1
# 1148        completely       0
# 1149        completely       2
# 1150        completely       1
# 1151        completely       1
# 1152        completely       1
# 1153        completely       1
# 1154        completely       1
# 1155        completely       1
# 1156        completely       0
# 1157  no_accessibility       1
# 1158  no_accessibility       0
# 1159  no_accessibility       0
# 1160  no_accessibility       1
#
# [1161 rows x 7 columns]

# %%
restaurants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1161 entries, 0 to 1160
# Data columns (total 7 columns):
# price             1161 non-null object
# parking_lot       1161 non-null object
# smoking_area      1161 non-null object
# other_services    1161 non-null object
# dress_code        1161 non-null object
# accessibility     1161 non-null object
# rating            1161 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 72.6+ KB

# %%
restaurants.price.unique()
# Out:
# array(['medium', 'low', 'high'], dtype=object)

# %%
restaurants.parking_lot.unique()
# Out:
# array(['none', 'yes', 'public', 'valet parking'], dtype=object)

# %%
restaurants.parking_lot[restaurants.parking_lot == "valet parking"] = "valet_parking"

# %%
restaurants.smoking_area.unique()
# Out:
# array(['not permitted', 'none', 'only at bar', 'section', 'permitted'],
#       dtype=object)

# %%
restaurants.smoking_area[restaurants.smoking_area == "not permitted"] = "not_permitted"
restaurants.smoking_area[restaurants.smoking_area == "only at bar"] = "only_at_bar"
# Out:
# /home/gunay/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
restaurants.other_services.unique()
# Out:
# array(['Internet', 'none', 'variety'], dtype=object)

# %%
restaurants.accessibility.unique()
# Out:
# array(['no_accessibility', 'completely', 'partially'], dtype=object)

# %%
restaurants.rating.unique()
# Out:
# array([0, 2, 1])

# %%
restaurants = pd.get_dummies(restaurants, drop_first=True)
restaurants.shape
# Out:
# (1161, 16)

# %%
len(restaurants.columns)
# Out:
# 16

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(restaurants.drop(["rating"],axis = 1),
                                                    restaurants.rating,test_size = 0.001,random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(max_depth=3, random_state=0)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %% [markdown]
# # Model serialization / marshalling

# %%
import _pickle as pickle
import requests,json
pickle.dump(model,open("random_forest.pkl","wb"))

# %%
model = pickle.load(open("random_forest.pkl","rb"))
model
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
X_val
# Out:
#      price_low  price_medium  parking_lot_public  parking_lot_valet_parking  \
# 915          1             0                   1                          0
# 590          0             1                   0                          0
#
#      parking_lot_yes  smoking_area_not_permitted  smoking_area_only_at_bar  \
# 915                0                           1                         0
# 590                0                           0                         0
#
#      smoking_area_permitted  smoking_area_section  other_services_none  \
# 915                       0                     0                    1
# 590                       0                     0                    1
#
#      other_services_variety  dress_code_formal  dress_code_informal  \
# 915                       0                  0                    0
# 590                       0                  0                    1
#
#      accessibility_no_accessibility  accessibility_partially
# 915                               1                        0
# 590                               1                        0

# %%
X = X_val.iloc[0,:].to_json(orient='split')
X = json.loads(X)
X = json.dumps({'ad':3.4})
url = "http://localhost:8088/api"
r = requests.post(url, X)
print (r.json())

#model.predict(np.array(X["data"]).reshape(1,-1))
# Out:
# <Response [500]>
